# %%
#OpenCV code
import cv2 
import matplotlib.pyplot as plt 

img = cv2.imread(r"C:\Users\Anuradha\Downloads\rh.jpeg")
circle = cv2.circle(img,(100,100),50,(0,0,255),-1)

rgb = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

plt.imshow(rgb)
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(299.5), np.float64(167.5), np.float64(-0.5))
