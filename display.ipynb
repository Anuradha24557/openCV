# %%
from skimage import io
img = io.imread(r"C:\Users\Anuradha\Downloads\flower.jpg")
io.imshow(img)
# Out:
# C:\Users\Anuradha\AppData\Local\Temp\ipykernel_18956\1795733173.py:3: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(img)
