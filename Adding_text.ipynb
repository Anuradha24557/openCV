# %%
import cv2
import matplotlib.pyplot as plt

img = cv2.imread(r"C:\Users\Anuradha\Downloads\meme.jpeg")

cv2.putText(img,"Ehhh?",(175,500),cv2.FONT_HERSHEY_SIMPLEX,2,(255,255,255),4,cv2.LINE_AA)

og = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

plt.imshow(og)
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(553.5), np.float64(553.5), np.float64(-0.5))
